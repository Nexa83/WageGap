# %%
wagegap = read.csv("GenderGapData.csv")

# %%
wagegap
# Out:
#     Occupation                                                All_workers
# 1   ALL OCCUPATIONS                                           109080
# 2   MANAGEMENT                                                 12480
# 3   Chief executives                                            1046
# 4   General and operations managers                              823
# 5   Legislators                                                    8
# 6   Advertising and promotions managers                           55
# 7   Marketing and sales managers                                 948
# 8   Public relations and fundraising managers                     59
# 9   Administrative services managers                             170
# 10  Computer and information systems managers                    636
# 11  Financial managers                                          1124
# 12  Compensation and benefits managers                            23
# 13  Human resources managers                                     254
# ...
